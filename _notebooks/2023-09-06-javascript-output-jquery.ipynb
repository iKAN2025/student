# %% [markdown]
# ---
# title: HTML Table Hacks With Javascript
# courses: {'compsci': {'week': 3} }
# type: hacks
# layout: default
# ---

# %% [markdown]
# ### Markdown Table
# Google [markdown cheat sheet](https://www.markdownguide.org/extended-syntax/#tables) and it lead you to an outline for how to make a table.
#
# | Make | Model | Year | Color | Price |
# |------|-------|------|-------|-------|
# |Ford|Mustang|2022|Red|$35,000|
# |Toyota|Camry|2022|Silver|$25,00|
# |Tesla|Model S|2022|White|$80,000|
# |Cadillac|Broughan|1969|Black|$10,000|
# |Ford|F-350|1997|Green|$15,000|
# |Ford|Excursion|2003|Green|$25,000|
# |Ford|Ranger|2012|Red|$8,000|
# |Kuboto|L3301 Tractor|2015|Orange|$12,000|
# |Ford|Fusion Energi|2015|Green|$15,000|
# |Acura|XL|2006|Grey|$10,000|
# |Ford|F150 Lightning|2023|Grey|$70,000|

# %% [markdown]
# ## My Second Markdown Table
#
#
#
# Rather than making a table based on sites for web designing like I did earlier, I decided to make a more "data" oriented data table. Therefore, I decided to use the densities vs substances  data table.
#
#
# | Substance | Density |
# |------|-------|
# |Oil   |0.80g/ml|
# |Water |1.00g/ml|
# |Plastic|0.90g/ml|
# |Zinc   |0.258g/ml|
# |Tin    |0.264g/ml|
# |Chromium|0.259g/ml|

# %% [markdown]
# ### HTML Table
# I went to  [w3schools html table](https://www.w3schools.com/html/html_tables.asp) and replicated my previous table.  I also used the teacher's code to make my table interactive as well! Here is my table using Jquery to make my table interactive!

# %%
# %%html
# <!-- Head contains information to Support the Document -->
# <head>
#     <!-- load jQuery and DataTables output style and scripts -->
#     <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.4/css/jquery.dataTables.min.css">
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
# </head>
#
# <h2>HTML Cell Output from Jupyter</h2>
#
#
# <!-- Body contains the contents of the Document -->
# <body>
#     <table id="md_demo" class="table">
#         <thead>
#             <tr>
#                 <th>Substance</th>
#                 <th>Density</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td> Oil </td>
#                 <td>0.80 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Water </td>
#                 <td> 1.0 g/ml</td>
#             <tr>
#                     <td> Plastic </td>
#                     <td>0.90 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Zinc   </td>
#                 <td>0.258 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Tin </td>
#                 <td>0.264 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Chromium </td>
#                 <td>0.259 g/ml</td>
#             </tr>
#
#
#         </tbody>
#     </table>
# </body>
# Out:
# <!-- Head contains information to Support the Document -->
# <head>
#     <!-- load jQuery and DataTables output style and scripts -->
#     <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.4/css/jquery.dataTables.min.css">
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
# </head>
#
# <h2>HTML Cell Output from Jupyter</h2>
#
#
# <!-- Body contains the contents of the Document -->
# <body>
#     <table id="md_demo" class="table">
#         <thead>
#             <tr>
#                 <th>Substance</th>
#                 <th>Density</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td> Oil </td>
#                 <td>0.80 g/ml</td>
#             </tr>
# ...

# %% [markdown]
# ## HTML Table in Markdown Cell with JavaScript jquery
# JavaScript is a programming language that works with HTML data, CSS helps to style that data.  In this example, we are using JavaScript and CSS that was developed by others (3rd party).  Addithing the 3rd party code makes the table interactive.
# - Look at the href and src on lines inside of the lines in `<head>` tags.  This is adding code to our page from others.
# - Observe the `<script>` tags at the bottom of the page.  This is generating the interactive table, from the third party code, using the data `<table id="demo">` from the `<body>`.

# %% [markdown]
# <!-- Head contains information to Support the Document -->
# <head>
#     <!-- load jQuery and DataTables output style and scripts -->
#     <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.4/css/jquery.dataTables.min.css">
#     <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
#     <script>var define = null;</script>
#     <script type="text/javascript" language="javascript" src="https://cdn.datatables.net/1.13.4/js/jquery.dataTables.min.js"></script>
# </head>
# <h2>HTML Cell Output from Jupyter</h2>
#
# <!-- Body contains the contents of the Document -->
# <body>
#     <table id="demo">
#     <table class="table">
#         <thead>
#             <tr>
#                 <th>Substance</th>
#                 <th>Density</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td> Oil </td>
#                 <td>0.80 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Water </td>
#                 <td> 1.0 g/ml</td>
#             <tr>
#                     <td> Plastic </td>
#                     <td>0.90 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Zinc   </td>
#                 <td>0.258 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Tin </td>
#                 <td>0.264 g/ml</td>
#             </tr>
#             <tr>
#                 <td> Chromium </td>
#                 <td>0.259 g/ml</td>
#             </tr>
#
# </tbody>
#     </table>
# </body>
# <!-- Body contains the contents of the Document -->
#
# <!-- Script is used to embed executable code -->
# <script>
#     $("#md_demo").DataTable();
# </script>

# %% [markdown]
# ## Hacks
# This lesson teaches you about tables.  In this hack, it is important that you analze the difference in the styles of output shown.
# - Make your own tables, with data according to your interests.
# - Describe a benefit of a markdown table.
# - Try to Style the HTML table using w3schools.
# - Describe the difference between HTML and JavaScript.
# - Describe a benefit of a table that uses JavaScript.

# %% [markdown]
# ## Web Design Table
#
# I primarily used styling/table for my own table down below (Web Design) in HTML this time rather than markdown! It

# %% [markdown]
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width,initial-scale=1"> <!---for phone devices-->
#   <!--CSSS MEDIA QUERIEEEEEEEEEEES-->
#   <title>Basic HTML Table</title>
# </head>
#
# <body>
#   <table width="100%" border="1">
#   <style>
#   background-color {color:#96D4D4;}
# </style>
#     <thead>
#       <tr>
#         <th>Name</th>
#         <th>URL</th>
#         <th>RWD?</th>
#         <th>Windows</th>
#         <th>Macintosh</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>Adobe Dreamweaver</td>
#         <td>http://www.adobe.com/products/dreamweaver.html</td>
#         <td>yes</td>
#         <td>yes</td>
#         <td>yes</td>
#       </tr>
#       <tr>
#         <td>Macaw</td>
#         <td>http://macaw.co/</td>
#         <td>yes</td>
#         <td>yes</td>
#         <td>yes</td>
#       </tr>
#       <tr>
#         <td>Coffee Cup Responsive Layout Maker Pro</td>
#         <td>http://www.coffeecup.com/responsive-layout-maker-pro/</td>
#         <td>yes</td>
#         <td>yes</td>
#         <td>yes</td>
#       </tr>
#       <tr>
#         <td>Microsoft Notepad</td>
#         <td>http://www.notepad.org/</td>
#         <td>no</td>
#         <td>yes</td>
#         <td>no</td>
#       </tr>
#       <tr>
#         <td>Tummult Hype</td>
#         <td>http://tumult.com/hype/</td>
#         <td>no</td>
#         <td>no</td>
#         <td>yes</td>
#       </tr>
#     </tbody>
#   </table>
# </body>
#
# </html>

# %% [markdown]
# ### Hacks
# <p> <b> 1.Describe a benefit of a markdown table</b> </p>
# It is easy to visualize and use.
#
#
# <p> <b> 2.Try to Style the HTML table using w3schools.</b> </p>
# I tried changing the background color!
#
#
# <p> <b> 3.Describe the difference between HTML and JavaScript.</b> </p>
#
# HTML is a markdown language, while  JavaScript is an advanced programming language that makes web pages more interactive and dynamic.
#
# <p> <b>4.Describe a benefit of a table that uses JavaScript.</b>
# Makes the table more dynamic, interactive, and user-friendly.</p>
